# %%
# %pylab inline
import os
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import itertools as it
from decimal import Decimal
from hcluster import linkage, dendrogram, fcluster
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# Data
coders = ['AWRAXV1RIYR0M', 'A23S6QOSZH9TMT', 'A21IFZJ0EDKM4E', 'AO3XB5I5QNNUI', 'A3RLCGRXA34GC0', 'A21SF3IKIZB0VN', 'APXNY64HXO08K', 'AM155T4U3RE1A', 'A2YBGZ2H2KSO5T']
labels = ['$%i$' % i for i in range(0, len(coders))]
distances = [Decimal('0.4107142857142857142857142857'), Decimal('0.2619047619047619047619047619'), Decimal('0.5'), Decimal('0.3518518518518518518518518519'), Decimal('0.5416666666666666666666666667'), Decimal('0.6'), Decimal('0.5178571428571428571428571429'), Decimal('0.5'), Decimal('0.4074074074074074074074074074'), Decimal('0.6538461538461538461538461538'), Decimal('0.4545454545454545454545454545'), Decimal('0.6166666666666666666666666667'), Decimal('0.6923076923076923076923076923'), Decimal('0.4516129032258064516129032258'), Decimal('0.6153846153846153846153846154'), Decimal('0.4722222222222222222222222222'), Decimal('0.5'), Decimal('0.5'), Decimal('0.6052631578947368421052631579'), Decimal('0.5370370370370370370370370370'), Decimal('0.4736842105263157894736842105'), Decimal('0.6538461538461538461538461538'), Decimal('0.5833333333333333333333333333'), Decimal('0.5769230769230769230769230769'), Decimal('0.7307692307692307692307692308'), Decimal('0.5'), Decimal('0.65'), Decimal('0.6923076923076923076923076923'), Decimal('0.4838709677419354838709677419'), Decimal('0.6153846153846153846153846154'), Decimal('0.5588235294117647058823529412'), Decimal('0.625'), Decimal('0.4411764705882352941176470588'), Decimal('0.6875'), Decimal('0.2272727272727272727272727273'), Decimal('0.66')]
coder_boundaries = [20, 26, 18, 10, 26, 16, 9, 23, 11]
coder_segments = dict()
coder_segments['AWRAXV1RIYR0M']	 = ['Pl', 'Pl', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Pl', 'Pl', 'Ex', 'Ex', 'Ex', 'Ev', 'De', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'Pl', 'Pl', 'Pl', 'Pl', 'Pl', 'Ex', 'Ex', 'Sc', 'Sc', 'Ex', 'Ex', 'Sc', 'Sc', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex', 'So/Ex', 'So/Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'St', 'St', 'St', 'St']
coder_segments['A23S6QOSZH9TMT']	= ['Ex/Pe', 'Sc/Ex', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Ev/So', 'Sc', 'Sc', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'Sc/Ev', 'Sc/Ev', 'Sc/Ev', 'Sc/Ev', 'Ex', 'Ex', 'Sc', 'Sc', 'Sc/So', 'Sc/So', 'Sc/Co', 'Sc/Co', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Pe', 'Ev', 'Ex', 'Ev', 'Ev']
coder_segments['A21IFZJ0EDKM4E']	= ['Ev', 'Ev', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Co/Ex', 'Ev', 'Ev', 'Ev', 'Co', 'Co', 'Co', 'De', 'De', 'Sc', 'Sc', 'Sc', 'Sc', 'Ev/Ex', 'Ev/Ex', 'Sc', 'Sc', 'So/Ex', 'So/Ex', 'Ex', 'Ex', 'So/Pe', 'So/Pe', 'So/Pe', 'So/Pe', 'So/Pe', 'So/Pe', 'So/Pe', 'So/Pe', 'So/Pe', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Pe', 'Pe', 'Pe', 'Pe']
coder_segments['AO3XB5I5QNNUI']	 = ['Pl', 'Pl', 'Pl', 'Pl', 'Pl', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'So/Ex', 'So/Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex/Pe', 'Ex/Pe', 'Ex/Pe', 'Ex/Pe', 'Ex/Pe', 'Ex/Pe', 'Ex/Pe', 'Ex/Pe', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex']
coder_segments['A3RLCGRXA34GC0']	= ['Sc/Ex', 'Sc/Ex', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Ex/Pe', 'Ex', 'Ev', 'Sc', 'Sc/So', 'Sc/So', 'Sc', 'Sc', 'So/Pe', 'Ex', 'So/Pe', 'So/Pe', 'So/Pe', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ev', 'Ev', 'Ev', 'Ex', 'Ex', 'Ex']
coder_segments['A21SF3IKIZB0VN']	= ['Ev', 'Ev', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Co/Pe', 'Co/Pe', 'Co/Pe', 'Co/Pe', 'Co/Pe', 'Ev/Co', 'Ev/Co', 'Ev/Co', 'Ev/Co', 'Sc/Co', 'Sc/Co', 'Sc/Ex', 'Sc/Ex', 'Sc/Ex', 'Sc/Ex', 'Sc/Ex', 'Sc/Ex', 'Ex', 'Ex', 'Sc/Ex', 'Sc/Ex', 'Sc/Ex', 'Sc/Ex', 'Sc/Ex', 'Sc/Ex', 'So/Pe', 'So/Pe', 'So/Pe', 'So/Pe', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Sc', 'Sc', 'St', 'St', 'Pe', 'Pe', 'Ex', 'Ex', 'Ex']
coder_segments['APXNY64HXO08K']	 = ['Pl', 'Pl', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'St', 'St', 'St', 'St', 'St', 'St', 'St']
coder_segments['AM155T4U3RE1A']	 = ['Pl', 'Ev', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Ev', 'Ex', 'Co', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'De', 'Sc', 'Sc', 'Sc', 'Ex', 'Ex', 'Ex', 'De', 'De', 'De', 'De', 'De', 'Sc', 'Sc', 'Sc', 'So/Pe', 'So/Pe', 'So/Pe', 'So/Pe', 'Ex', 'So', 'Ex', 'Ex', 'Ex', 'Ex', 'Pe', 'Pe', 'Ex', 'Ex', 'Ex']
coder_segments['A2YBGZ2H2KSO5T']	= ['Ev', 'Ev', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Sc', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'Ev', 'Sc', 'Sc', 'Sc', 'Sc', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'So/Ex/Pe', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex', 'Ex']

# %%
# Cluster
aglomerative_clusters = linkage(distances, method='complete')
dendro = dendrogram(aglomerative_clusters, labels=labels)
plt.ylabel('Mean Distance (1-B)')
plt.xlabel('Coder')
plt.show(dendro)

# %%
# Plot boundaries per coder
y = coder_boundaries
x = np.arange(len(y))
# Set up
width = 0.75
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# Plot
rects = ax.bar(x, y, width, color='0.75')
# Add xticks
ax.set_xticks(x + (width / 2))
ax.set_xticklabels([str(val) for val in labels])
# Draw mean lines
xmin, xmax, ymean, ystd = -0.25, len(labels), np.mean(y), np.std(y)
ax.plot([xmin, xmax], [ymean] * 2, color='k') # Draw mean
ax.plot([xmin, xmax], [ymean + ystd] * 2, color='0.5') # Draw +std
ax.plot([xmin, xmax], [ymean - ystd] * 2, color='0.5') # Draw -std
# Add numbers to bars
format_str='$%d$'
fnc_value=int
for rect in rects:
    height = rect.get_height()
    ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, format_str%fnc_value(height), ha='center', va='bottom')
# Format
ax.set_xlim([-0.25, 9])
ax.set_ylim([0, 30])
ax.set_xlabel('Coder')
ax.set_ylabel('Boundaries placed (quantity)')
plt.show()

# %%
# Compute label similarity
def jaccard(a, b):
    return float(len(a & b)) / float(len(a | b))

total_similarities = list()
row_similarities = list()
for i in xrange(0, 54):
    parts = list()
    for coder in coders:
        parts.append(set(coder_segments[coder][i].split('/')))
    part_combinations = it.combinations(parts, 2)
    similarities = [jaccard(a, b) for a, b in part_combinations]
    total_similarities.extend(similarities)
    row_similarities.append(similarities)

y_sim = list()
y_sim_err = list()
for row_similarity in row_similarities:
    y_sim.append(np.mean(row_similarity))
    y_sim_err.append(np.std(row_similarity))

# %%
# Plot mean label similarity
labels = ['$%i$' % i for i in range(0, 54)]

y = list(y_sim)
x = range(0, 54)
plt.errorbar(x, y, color='k', )

xlim([0, 53.0])
ylim([0, 1.05])

plt.ylabel('Mean Label Jaccard Similarity')
plt.xlabel('Line')

plt.show()
